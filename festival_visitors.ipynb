# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 충청남도

# %%
# 보령머드축제
dfmud = pd.read_csv('./data/chungsouth/20241125154240_보령머드축제_연도별 방문자 추이.csv', encoding='cp949')

# %%
dfmud
# Out:
#       축제명  개최년도  축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수   (전체)방문자수  \
# 0  보령머드축제  2018       10   122151.0   338694.0     1467.0   462312.0
# 1  보령머드축제  2019       10   117284.0   325715.0     1811.0   444810.0
# 2  보령머드축제  2022       31   449549.0  1213604.0      456.0  1663609.0
# 3  보령머드축제  2023       17   225506.0   614824.0     1660.0   841990.0
#
#      일평균 방문자수  전년도 일평균 방문자수  일평균 방문자수 증감률  (이전)전체방문자  (전체)방문자증감  (현지인)방문자비율  \
# 0  46231.2000           NaN           NaN        NaN   462312.0       26.42
# 1  44481.0000    46231.2000          -3.8   462312.0   -17502.0       26.37
# 2  53664.8065    44481.0000          20.6   444810.0  1218799.0       27.02
# 3  49528.8235    53664.8065          -7.7  1663609.0  -821619.0       26.78
#
#    (외지인)방문자비율  (외국인)방문자비율  전년대비방문자증감비율
# 0       73.26        0.32         0.00
# 1       73.23        0.41        -3.79
# 2       72.95        0.03       274.00
# 3       73.02        0.20       -49.39

# %%
dfmud_human = dfmud.set_index('개최년도').iloc[:,1:6]
dfmud_human['outsiders'] = (dfmud_human['(외지인)방문자수'] + dfmud_human['(외국인)방문자수']) / dfmud_human['(전체)방문자수']
dfmud_human['ave'] = dfmud_human['(전체)방문자수'] / dfmud_human['축체기간(일)']

# %%
dfmud_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수   (전체)방문자수  outsiders  \
# 개최년도
# 2018       10   122151.0   338694.0     1467.0   462312.0   0.735782
# 2019       10   117284.0   325715.0     1811.0   444810.0   0.736328
# 2022       31   449549.0  1213604.0      456.0  1663609.0   0.729775
# 2023       17   225506.0   614824.0     1660.0   841990.0   0.732175
#
#                ave
# 개최년도
# 2018  46231.200000
# 2019  44481.000000
# 2022  53664.806452
# 2023  49528.823529

# %%
# 금산인삼축제
dfch1 = pd.read_csv('./data/chungsouth/20241125154050_금산인삼축제_연도별 방문자 추이.csv',encoding='cp949')

# %%
dfch1_human = dfch1.set_index('개최년도').iloc[:,1:6]
dfch1_human['outsiders'] = (dfch1_human['(외지인)방문자수'] + dfch1_human['(외국인)방문자수']) / dfch1_human['(전체)방문자수']
dfch1_human['ave'] = dfch1_human['(전체)방문자수'] / dfch1_human['축체기간(일)']

# %%
dfch1_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders  \
# 개최년도
# 2018       10   215278.0   224894.0      443.0  440615.0   0.511415
# 2019       10   232728.0   225600.0     2305.0  460633.0   0.494765
# 2022       11   300315.0   267140.0       56.0  567511.0   0.470821
# 2023       10   297531.0   253536.0      432.0  551499.0   0.460505
#
#                ave
# 개최년도
# 2018  44061.500000
# 2019  46063.300000
# 2022  51591.909091
# 2023  55149.900000

# %%
# 강경젓갈축제
dfch2 = pd.read_csv('./data/chungsouth/20241125153254_강경젓갈축제_연도별 방문자 추이.csv', encoding='cp949')
dfch2_human = dfch2.set_index('개최년도').iloc[:,1:6]
dfch2_human['outsiders'] = (dfch2_human['(외지인)방문자수'] + dfch2_human['(외국인)방문자수']) / dfch2_human['(전체)방문자수']
dfch2_human['ave'] = dfch2_human['(전체)방문자수'] / dfch2_human['축체기간(일)']

# %%
dfch2_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders       ave
# 개최년도
# 2018        5    50642.0    59291.0      108.0  110041.0   0.539790  22008.20
# 2022        5    57971.0    69910.0       19.0  127900.0   0.546747  25580.00
# 2023        4    52282.0    71999.0       18.0  124299.0   0.579385  31074.75

# %%
# 한산모시문화제
dfch3 = pd.read_csv('./data/chungsouth/20241125155615_한산모시문화제_연도별 방문자 추이.csv', encoding='cp949')
dfch3_human = dfch3.set_index('개최년도').iloc[:,1:6]
dfch3_human['outsiders'] = (dfch3_human['(외지인)방문자수'] + dfch3_human['(외국인)방문자수']) / dfch3_human['(전체)방문자수']
dfch3_human['ave'] = dfch3_human['(전체)방문자수'] / dfch3_human['축체기간(일)']

# %%
dfch3_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders       ave
# 개최년도
# 2018        4    20801.0    19163.0       15.0   39979.0   0.479702   9994.75
# 2019        4    19404.0    18231.0       55.0   37690.0   0.485168   9422.50
# 2022        3    21062.0    17472.0        4.0   38538.0   0.453474  12846.00
# 2023        3    14713.0    15316.0        1.0   30030.0   0.510057  10010.00

# %%
# 천안흥타령축제
dfch4 = pd.read_csv('./data/chungsouth/20241125155251_천안흥타령축제_연도별 방문자 추이.csv',encoding='cp949')
dfch4_human = dfch4.set_index('개최년도').iloc[:,1:6]
dfch4_human['outsiders'] = (dfch4_human['(외지인)방문자수'] + dfch4_human['(외국인)방문자수']) / dfch4_human['(전체)방문자수']
dfch4_human['ave'] = dfch4_human['(전체)방문자수'] / dfch4_human['축체기간(일)']

# %%
dfch4_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders      ave
# 개최년도
# 2018        5   141008.0   173032.0     1444.0  315484.0   0.553042  63096.8
# 2019        5    83362.0    49948.0      231.0  133541.0   0.375757  26708.2
# 2022        5   112893.0    75921.0       73.0  188887.0   0.402325  37777.4
# 2023        5   106685.0    76898.0      411.0  183994.0   0.420171  36798.8

# %%
# 서산해미읍성축제
dfch5 = pd.read_csv('./data/chungsouth/20241125154340_서산해미읍성축제_연도별 방문자 추이.csv',encoding='cp949')
dfch5_human = dfch5.set_index('개최년도').iloc[:,1:6]
dfch5_human['outsiders'] = (dfch5_human['(외지인)방문자수'] + dfch5_human['(외국인)방문자수']) / dfch5_human['(전체)방문자수']
dfch5_human['ave'] = dfch5_human['(전체)방문자수'] / dfch5_human['축체기간(일)']

# %%
dfch5_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders  \
# 개최년도
# 2018        3    42045.0    44467.0       69.0   86581.0   0.514385
# 2019        3    41976.0    56389.0       45.0   98410.0   0.573458
# 2022        3    41519.0    44649.0       20.0   86188.0   0.518274
# 2023        3    43239.0    46942.0       40.0   90221.0   0.520744
#
#                ave
# 개최년도
# 2018  28860.333333
# 2019  32803.333333
# 2022  28729.333333
# 2023  30073.666667

# %%
# 석장리세계구석기축제
dfch6 = pd.read_csv('./data/chungsouth/20241125154343_석장리세계구석기축제_연도별 방문자 추이.csv',encoding='cp949')
dfch6_human = dfch6.set_index('개최년도').iloc[:,1:6]
dfch6_human['outsiders'] = (dfch6_human['(외지인)방문자수'] + dfch6_human['(외국인)방문자수']) / dfch6_human['(전체)방문자수']
dfch6_human['ave'] = dfch6_human['(전체)방문자수'] / dfch6_human['축체기간(일)']

# %%
dfch6_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders  \
# 개최년도
# 2018        4    27628.0    39349.0       14.0   66991.0   0.587586
# 2019        4    34880.0    52960.0       12.0   87852.0   0.602969
# 2022        4    37608.0    39184.0        2.0   76794.0   0.510274
# 2023        3    30681.0    23278.0       10.0   53969.0   0.431507
#
#                ave
# 개최년도
# 2018  16747.750000
# 2019  21963.000000
# 2022  19198.500000
# 2023  17989.666667

# %%
plt.figure(figsize=(10,10))
plt.plot(dfmud_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch1_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch2_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch3_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch4_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch5_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch6_human.loc[:,'(전체)방문자수'],'-o')
plt.legend(labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone'])
plt.title('Chungcheong South: total visitors')
plt.show()

# %%
# 축제 기간 중 일일 평균 방문자 수
plt.figure(figsize=(10,10))
plt.plot(dfmud_human.loc[:,'ave'],'-o')
plt.plot(dfch1_human.loc[:,'ave'],'-o')
plt.plot(dfch2_human.loc[:,'ave'],'-o')
plt.plot(dfch3_human.loc[:,'ave'],'-o')
plt.plot(dfch4_human.loc[:,'ave'],'-o')
plt.plot(dfch5_human.loc[:,'ave'],'-o')
plt.plot(dfch6_human.loc[:,'ave'],'-o')
plt.legend(loc=1,labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone'])
plt.title('Chungcheong South: average visitors per day')
plt.ylim(0,80000)
plt.show()

# %%
# 전체 방문자 중 외부인 비율
plt.figure(figsize=(10,10))
plt.plot(dfmud_human.loc[:,'outsiders'],'-o')
plt.plot(dfch1_human.loc[:,'outsiders'],'-o')
plt.plot(dfch2_human.loc[:,'outsiders'],'-o')
plt.plot(dfch3_human.loc[:,'outsiders'],'-o')
plt.plot(dfch4_human.loc[:,'outsiders'],'-o')
plt.plot(dfch5_human.loc[:,'outsiders'],'-o')
plt.plot(dfch6_human.loc[:,'outsiders'],'-o')
plt.legend(loc=2,labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone'])
plt.title('Chungcheong South: ratio of outsiders')
plt.ylim(0,1)
plt.show()

# %% [markdown]
# # 충청북도

# %%
# 괴산고추축제
dfcb1 = pd.read_csv('./data/chungnorth/20241125154038_괴산고추축제_연도별 방문자 추이.csv',encoding='cp949')
dfcb1_human = dfcb1.set_index('개최년도').iloc[:,1:6]
dfcb1_human['outsiders'] = (dfcb1_human['(외지인)방문자수'] + dfcb1_human['(외국인)방문자수']) / dfcb1_human['(전체)방문자수']
dfcb1_human['ave'] = dfcb1_human['(전체)방문자수'] / dfcb1_human['축체기간(일)']

# %%
dfcb1_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders       ave
# 개최년도
# 2018        4    38254.0    53578.0       75.0   91907.0   0.583775  22976.75
# 2019        4    39975.0    70971.0      152.0  111098.0   0.640183  27774.50
# 2022        4    50340.0    61335.0        9.0  111684.0   0.549264  27921.00
# 2023        4    52928.0    79873.0       58.0  132859.0   0.601623  33214.75

# %%
#영동난계국악축제
dfcb2 = pd.read_csv('./data/chungnorth/20241125154909_영동난계국악축제_연도별 방문자 추이.csv',encoding='cp949')
dfcb2_human = dfcb2.set_index('개최년도').iloc[:,1:6]
dfcb2_human['outsiders'] = (dfcb2_human['(외지인)방문자수'] + dfcb2_human['(외국인)방문자수']) / dfcb2_human['(전체)방문자수']
dfcb2_human['ave'] = dfcb2_human['(전체)방문자수'] / dfcb2_human['축체기간(일)']

# %%
dfcb2_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders       ave
# 개최년도
# 2018        4    92918.0    44896.0       33.0  137847.0   0.325934  34461.75
# 2019        4    88518.0    45423.0      378.0  134319.0   0.340987  33579.75
# 2022        4    99615.0    48682.0      155.0  148452.0   0.328975  37113.00
# 2023        4   102361.0    46733.0      122.0  149216.0   0.314008  37304.00

# %%
#옥천 지용제
dfcb3 = pd.read_csv('./data/chungnorth/20241125155153_지용제_연도별 방문자 추이.csv',encoding='cp949')
dfcb3_human = dfcb3.set_index('개최년도').iloc[:,1:6]
dfcb3_human['outsiders'] = (dfcb3_human['(외지인)방문자수'] + dfcb3_human['(외국인)방문자수']) / dfcb3_human['(전체)방문자수']
dfcb3_human['ave'] = dfcb3_human['(전체)방문자수'] / dfcb3_human['축체기간(일)']

# %%
dfcb3_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders      ave
# 개최년도
# 2018        4    99119.0    53603.0       60.0  152782.0   0.351239  38195.5
# 2019        4   103208.0    71134.0       76.0  174418.0   0.408272  43604.5
# 2022        4   119926.0    65540.0       34.0  185500.0   0.353499  46375.0
# 2023        4   114939.0    69600.0       45.0  184584.0   0.377308  46146.0

# %%
# 음성품바축제
dfcb4 = pd.read_csv('./data/chungnorth/20241125155007_음성품바축제_연도별 방문자 추이.csv',encoding='cp949')
dfcb4_human = dfcb4.set_index('개최년도').iloc[:,1:6]
dfcb4_human['outsiders'] = (dfcb4_human['(외지인)방문자수'] + dfcb4_human['(외국인)방문자수']) / dfcb4_human['(전체)방문자수']
dfcb4_human['ave'] = dfcb4_human['(전체)방문자수'] / dfcb4_human['축체기간(일)']

# %%
dfcb4_human
# Out:
#       축체기간(일)  (현지인)방문자수  (외지인)방문자수  (외국인)방문자수  (전체)방문자수  outsiders      ave
# 개최년도
# 2018        5    85312.0    90314.0      149.0  175775.0   0.514652  35155.0
# 2019        5    89176.0   103489.0      412.0  193077.0   0.538132  38615.4
# 2022        5   105161.0    89717.0       15.0  194893.0   0.460417  38978.6
# 2023        5   106527.0    78421.0       82.0  185030.0   0.424272  37006.0

# %%
# 축제 기간 전체 방문자 수
plt.figure(figsize=(10,10))
plt.plot(dfcb1_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb2_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb3_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb4_human.loc[:,'(전체)방문자수'],'-v')
plt.legend(labels=['gwesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong North: total visitors')
plt.show()

# %%
# 축제 기간 중 일일 평균 방문자 수
plt.figure(figsize=(10,10))
plt.plot(dfcb1_human.loc[:,'ave'],'-v')
plt.plot(dfcb2_human.loc[:,'ave'],'-v')
plt.plot(dfcb3_human.loc[:,'ave'],'-v')
plt.plot(dfcb4_human.loc[:,'ave'],'-v')
plt.legend(labels=['gwesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong North: average visitors per day')
plt.show()

# %%
# 전체 방문자 중 외부인 비율
plt.figure(figsize=(10,10))
plt.plot(dfcb1_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb2_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb3_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb4_human.loc[:,'outsiders'],'-v')
plt.legend(labels=['gwesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong North: ratio of outsiders')
plt.show()

# %% [markdown]
# # 충청도 전체

# %%
# 축제 기간 전체 방문자 수
figure = plt.figure(figsize=(10,10))
plt.plot(dfmud_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch1_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch2_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch3_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch4_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch5_human.loc[:,'(전체)방문자수'],'-o')
plt.plot(dfch6_human.loc[:,'(전체)방문자수'],'-o')

plt.plot(dfcb1_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb2_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb3_human.loc[:,'(전체)방문자수'],'-v')
plt.plot(dfcb4_human.loc[:,'(전체)방문자수'],'-v')

plt.legend(labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone',
                   'goesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong: total visitors')
plt.show()

# %%
# 축제 기간 중 일일 평균 방문자 수
plt.figure(figsize=(10,10))

plt.plot(dfmud_human.loc[:,'ave'],'-o')
plt.plot(dfch1_human.loc[:,'ave'],'-o')
plt.plot(dfch2_human.loc[:,'ave'],'-o')
plt.plot(dfch3_human.loc[:,'ave'],'-o')
plt.plot(dfch4_human.loc[:,'ave'],'-o')
plt.plot(dfch5_human.loc[:,'ave'],'-o')
plt.plot(dfch6_human.loc[:,'ave'],'-o')

plt.plot(dfcb1_human.loc[:,'ave'],'-v')
plt.plot(dfcb2_human.loc[:,'ave'],'-v')
plt.plot(dfcb3_human.loc[:,'ave'],'-v')
plt.plot(dfcb4_human.loc[:,'ave'],'-v')

plt.legend(labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone',
                   'goesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong: average visitors per day')
plt.ylim(0,80000)
plt.show()

# %%
# 축제 기간 중 일일 평균 방문자 수
plt.figure(figsize=(10,10))
plt.plot(dfmud_human.loc[:,'outsiders'],'-o')
plt.plot(dfch1_human.loc[:,'outsiders'],'-o')
plt.plot(dfch2_human.loc[:,'outsiders'],'-o')
plt.plot(dfch3_human.loc[:,'outsiders'],'-o')
plt.plot(dfch4_human.loc[:,'outsiders'],'-o')
plt.plot(dfch5_human.loc[:,'outsiders'],'-o')
plt.plot(dfch6_human.loc[:,'outsiders'],'-o')
plt.plot(dfcb1_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb2_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb3_human.loc[:,'outsiders'],'-v')
plt.plot(dfcb4_human.loc[:,'outsiders'],'-v')
plt.legend(loc=2, ncols=2, labels=['boryung_mud','geumsan_insam','gangyeong_jeotgal','hansan_moshi',
                   'cheonan_heung','seosan_haemi','seokjanglee_old_stone',
                   'goesan_pepper','yeongdong_nangye','jiyong','eumseong_pumba'])
plt.title('Chungcheong: ratio of outsiders')
plt.ylim(0,1)
plt.show()
